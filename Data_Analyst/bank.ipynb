# %%
import pandas as pd

# %%
df = pd.read_excel('VN Bank.xlsx')
df.head()
# Out:
#   Bank Code    Year Number of Employees Number of Branches  \
# 0       NaN     NaN                  NE                 NB
# 1       ABB  2005.0                  94                NaN
# 2       ABB  2006.0                 309                 14
# 3       ABB  2007.0                1123                 54
# 4       ABB  2008.0                1345                 70
#
#   Labour productivity Network productivity Employees Ratio Branches Ratio  \
# 0               LPROD                NPROD          ERATIO         BRATIO
# 1           87.553191                  NaN        0.001387            NaN
# 2           41.016181           905.285714        0.004281       0.003501
# 3           144.05699          2995.851852        0.011123       0.013012
# 4           36.948699           709.942857        0.010816       0.000354
#
#   Total Deposits Total Shareholder's Equity  ... Returns Over Assets  \
# 0       DEPOSITS                     EQUITY  ...                 ROA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 48 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Bank Code                          631 non-null    object
#  1   Year                               631 non-null    float64
#  2   Number of Employees                469 non-null    object
#  3   Number of Branches                 434 non-null    object
#  4   Labour productivity                467 non-null    object
#  5   Network productivity               432 non-null    object
#  6   Employees Ratio                    469 non-null    object
#  7   Branches Ratio                     434 non-null    object
#  8   Total Deposits                     632 non-null    object
#  9   Total Shareholder's Equity         632 non-null    object
#  10  Total Loans                        631 non-null    object
# ...

# %%
df.describe(include="all")
# Out:
#        Bank Code         Year  Number of Employees  Number of Branches  \
# count        631   631.000000                469.0               434.0
# unique        45          NaN                453.0               249.0
# top          AGB          NaN                 98.0                91.0
# freq          20          NaN                  3.0                11.0
# mean         NaN  2012.026941                  NaN                 NaN
# std          NaN     5.064746                  NaN                 NaN
# min          NaN  2002.000000                  NaN                 NaN
# 25%          NaN  2008.000000                  NaN                 NaN
# 50%          NaN  2012.000000                  NaN                 NaN
# 75%          NaN  2016.000000                  NaN                 NaN
# max          NaN  2021.000000                  NaN                 NaN
#
#        Labour productivity Network productivity  Employees Ratio  \
# ...

# %%
df.isna().sum()
# Out:
# Bank Code                              1
# Year                                   1
# Number of Employees                  163
# Number of Branches                   198
# Labour productivity                  165
# Network productivity                 200
# Employees Ratio                      163
# Branches Ratio                       198
# Total Deposits                         0
# Total Shareholder's Equity             0
# Total Loans                            1
# Loan Loss Provisions                  28
# Non-performing Loans                  54
# Total Fixed Assets                     2
# Liquid Assets                          5
# Total Assets                           4
# Total Deposits Ratio                   0
# Total Loans Ratio                      1
# Total Assets Ratio                     4
# Interest Expenses                      5
# Non-Interest Expenses                  6
# Personnel Expenses                   134
# Occupancy Expenses                   139
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 627    False
# 628    False
# 629    False
# 630    False
# 631    False
# Length: 632, dtype: bool

# %%
df.isnull().sum()
# Out:
# Bank Code                              1
# Year                                   1
# Number of Employees                  163
# Number of Branches                   198
# Labour productivity                  165
# Network productivity                 200
# Employees Ratio                      163
# Branches Ratio                       198
# Total Deposits                         0
# Total Shareholder's Equity             0
# Total Loans                            1
# Loan Loss Provisions                  28
# Non-performing Loans                  54
# Total Fixed Assets                     2
# Liquid Assets                          5
# Total Assets                           4
# Total Deposits Ratio                   0
# Total Loans Ratio                      1
# Total Assets Ratio                     4
# Interest Expenses                      5
# Non-Interest Expenses                  6
# Personnel Expenses                   134
# Occupancy Expenses                   139
# ...

# %%
df["Bank Code"].unique()
df["Bank Code"].dropna(inplace=True)
df["Bank Code"].value_counts()
# Out:
# AGB     20
# BIDV    20
# CTG     20
# ACB     20
# VCB     20
# TCB     20
# MB      19
# VPB     19
# SGB     18
# STB     18
# VCPB    18
# KLB     18
# VAB     18
# SEAB    18
# ABB     17
# MSB     17
# NAB     17
# HDB     17
# VBSP    17
# EIB     17
# VIB     17
# SHB     16
# NCB     16
# OCB     16
# LVB     14
# TPB     14
# DAB     14
# PGB     14
# HSBC    13
# SCB     13
# IVB     12
# MHB     11
# MDB     11
# WEB     11
# BAB     10
# PNB      9
# HBB      9
# PVB      8
# OB       8
# BVB      8
# GAB      6
# TNB      4
# CB       4
# FCB      3
# GPB      2
# Name: Bank Code, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# df.drop(["index"],axis=1)
# Out:
#   Bank Code    Year Number of Employees Number of Branches  \
# 2       ABB  2006.0                 309                 14
# 3       ABB  2007.0                1123                 54
# 4       ABB  2008.0                1345                 70
# 5       ABB  2009.0                1717                 86
# 7       ABB  2011.0                2683                133
#
#   Labour productivity Network productivity Employees Ratio Branches Ratio  \
# 2           41.016181           905.285714        0.004281       0.003501
# 3           144.05699          2995.851852        0.011123       0.013012
# 4           36.948699           709.942857        0.010816       0.000354
# 5          181.506698          3623.802326        0.012404       0.000427
# 7          114.441297          2308.616541        0.015506       0.007212
#
#   Total Deposits Total Shareholder's Equity  ... Returns Over Assets  \
# 2        1551159                    1190274  ...            0.407014
# ...
